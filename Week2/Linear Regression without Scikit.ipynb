# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('penguins_regression.csv')

# %%
data, target = df[['Flipper Length (mm)']], df['Body Mass (g)']

# %%
sns.scatterplot(data=df, x='Flipper Length (mm)', y='Body Mass (g)', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='Flipper Length (mm)', ylabel='Body Mass (g)'>

# %% [markdown]
# # y=mx + c

# %%
def linear_model_flipper_mass(flipper_length, weight_flipper_length, intercept_body_mass):
    body_mass = weight_flipper_length*flipper_length + intercept_body_mass
    return body_mass

# %%
m = 45
c = -5000

flipper_length_range = np.linspace(data.min(), data.max(), num=300)
predicted_body_mass = linear_model_flipper_mass(flipper_length_range, m, c)

# %%
sns.scatterplot(data=df, x='Flipper Length (mm)', y='Body Mass (g)', alpha=0.5, color='red')
plt.plot(flipper_length_range, predicted_body_mass)

# %% [markdown]
# ### in case of -ve slope

# %%
m = -40
c = 13000

flipper_length_range = np.linspace(data.min(), data.max(), num=300)
predicted_body_mass = linear_model_flipper_mass(flipper_length_range, m, c)

sns.scatterplot(data=df, x='Flipper Length (mm)', y='Body Mass (g)', alpha=0.5, color='red')
plt.plot(flipper_length_range, predicted_body_mass)

# %%
body_mass_180 = linear_model_flipper_mass(flipper_length=180, weight_flipper_length=40, intercept_body_mass=0)
body_mass_181 = linear_model_flipper_mass(flipper_length=181, weight_flipper_length=40, intercept_body_mass=0)
print(f"The body mass for a flipper length of 180 mm is {body_mass_180} g and {body_mass_181} g for a flipper length of 181 mm")
# Out:
# The body mass for a flipper length of 180 mm is 7200 g and 7240 g for a flipper length of 181 mm
