# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
    
    lr=0.001
    n_iters=1000
    m = []
    def fit(X, y):
        # init parameters
        n_samples, n_features = X.shape
        m = np.zeros(n_features)
        c = 0
        
        for _ in range(n_iters):
            y_predicted = np.dot(X, m) + c
            
            dm = (1/n_samples)*np.dot(X.T, (y_predicted-y))
            dc = (1/n_samples)*np.sum(y_predicted-y)
            
            m -= lr * dm
            c -= lr * dc
            
            
    def predict(X):
        y_predicted = np.dot(X, m) + bias
        return y_predicted

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
X, y = datasets.make_regression(n_samples=1000, n_features=1, noise=20, random_state=4)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
print(X[:,0]) # [ first_row:last_row , column_0 ]
# Out:
# [-2.07353938e-01  1.83626319e-01  3.38252932e-01  2.82206663e-01
#  -1.34746030e+00  5.49507581e-01  6.79721934e-02 -7.96742673e-01
#  -2.29291305e+00 -1.16156742e+00 -3.31452555e-01 -2.61312042e-01
#  -7.51870758e-01 -4.94258387e-02 -1.02091898e+00 -4.55212069e-01
#  -9.90913221e-01 -9.92154736e-02 -1.16829028e+00  5.33652814e-01
#   4.94765430e-02 -3.16299786e-01 -4.95818520e-01 -7.44229701e-01
#   8.19067335e-01  1.34176007e+00  3.51423233e-01 -6.00242818e-02
#   2.37732560e-01 -5.53372855e-01 -7.57822191e-01 -1.69217314e+00
#   5.73528153e-02 -7.41688415e-01  9.83864622e-01  5.74612568e-01
#   1.97869001e-01 -2.61853812e-01 -5.76829553e-01  1.13511967e+00
#   4.57906217e-01  1.43731603e+00 -2.54808898e-01  7.18274389e-01
#   1.24035938e-01 -1.26244101e+00 -1.60451349e+00  2.03217933e+00
#  -8.79869283e-02 -8.94120495e-01  4.84372449e-01  1.77753323e-01
#   9.72848539e-02 -3.95259451e-01 -5.71501058e-01 -1.58530086e+00
# ...

# %%
sns.scatterplot(X[:,0],y)
# Out:
# <AxesSubplot:>

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (800, 1)
# (800,)

# %%
def mse(y_true, y_predicted):
    return np.mean((y_true-y_predicted)**2)

# %%
fit(X_train, y_train)

# %%
predicted = predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-6499b4599dd8> in <module>
# ----> 1 predicted = predict(X_test)
#
# <ipython-input-79-424cb2bf7cb8> in predict(X)
#      19
#      20 def predict(X):
# ---> 21     y_predicted = np.dot(X, m) + bias
#      22     return y_predicted
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (200,1) and (0,) not aligned: 1 (dim 1) != 0 (dim 0)
