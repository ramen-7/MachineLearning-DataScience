# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('SA2021_W1_Pokemon.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.drop('#', axis = 1, inplace=True)

# %%
df.Name.sort_values(ascending=True)
# Out:
# 510                  Abomasnow
# 511    AbomasnowMega Abomasnow
# 68                        Abra
# 392                      Absol
# 393            AbsolMega Absol
#                 ...
# 632                    Zoroark
# 631                      Zorua
# 46                       Zubat
# 695                   Zweilous
# 794           Zygarde50% Forme
# Name: Name, Length: 800, dtype: object

# %%
df.sort_values('Name')
# Out:
#                         Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 510                Abomasnow    Grass     Ice    494   90      92       75
# 511  AbomasnowMega Abomasnow    Grass     Ice    594   90     132      105
# 68                      Abra  Psychic     NaN    310   25      20       15
# 392                    Absol     Dark     NaN    465   65     130       60
# 393          AbsolMega Absol     Dark     NaN    565   65     150       60
# ..                       ...      ...     ...    ...  ...     ...      ...
# 632                  Zoroark     Dark     NaN    510   60     105       60
# 631                    Zorua     Dark     NaN    330   40      65       40
# 46                     Zubat   Poison  Flying    245   40      45       35
# 695                 Zweilous     Dark  Dragon    420   72      85       70
# 794         Zygarde50% Forme   Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Attack', 'HP'])
# Out:
#                         Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 488                  Happiny   Normal       NaN    220  100       5        5
# 121                  Chansey   Normal       NaN    450  250       5        5
# 139                 Magikarp    Water       NaN    200   20      10       55
# 230                  Shuckle      Bug      Rock    505   20      10      230
# 261                  Blissey   Normal       NaN    540  255      10       10
# ..                       ...      ...       ...    ...  ...     ...      ...
# 429       DeoxysAttack Forme  Psychic       NaN    600   50     180       20
# 424    GroudonPrimal Groudon   Ground      Fire    770  100     180      160
# 426    RayquazaMega Rayquaza   Dragon    Flying    780  105     180      100
# 232  HeracrossMega Heracross      Bug  Fighting    600   80     185      115
# 163      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
#
# ...

# %%
strong = df.Attack >= 150
strong
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796     True
# 797    False
# 798     True
# 799    False
# Name: Attack, Length: 800, dtype: bool

# %%
df[df.Attack >= 150]
# Out:
#                         Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 19     BeedrillMega Beedrill      Bug    Poison    495   65     150       40
# 137        PinsirMega Pinsir      Bug    Flying    600   65     155      120
# 141    GyaradosMega Gyarados    Water      Dark    640   95     155      109
# 163      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 164      MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150       70
# 229        ScizorMega Scizor      Bug     Steel    600   70     150      140
# 232  HeracrossMega Heracross      Bug  Fighting    600   80     185      115
# 268  TyranitarMega Tyranitar     Rock      Dark    700  100     164      150
# 279    BlazikenMega Blaziken     Fire  Fighting    630   80     160       80
# 283    SwampertMega Swampert    Water    Ground    635  100     150      110
# 313                  Slaking   Normal       NaN    670  150     160      100
# ...

# %%
 df[(df.Attack >= 150) | (df['Type 1'] == 'Poison')]
# Out:
#                         Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 19     BeedrillMega Beedrill      Bug    Poison    495   65     150       40
# 28                     Ekans   Poison       NaN    288   35      60       44
# 29                     Arbok   Poison       NaN    438   60      85       69
# 34                  Nidoran♀   Poison       NaN    275   55      47       52
# 35                  Nidorina   Poison       NaN    365   70      62       67
# 36                 Nidoqueen   Poison    Ground    505   90      92       87
# 37                  Nidoran♂   Poison       NaN    273   46      57       40
# 38                  Nidorino   Poison       NaN    365   61      72       57
# 39                  Nidoking   Poison    Ground    505   81     102       77
# 46                     Zubat   Poison    Flying    245   40      45       35
# 47                    Golbat   Poison    Flying    455   75      80       70
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
for index, row in df.iterrows():
    print(index, row.Attack, row.Defense)
# Out:
# 0 49 49
# 1 62 63
# 2 82 83
# 3 100 123
# 4 52 43
# 5 64 58
# 6 84 78
# 7 130 111
# 8 104 78
# 9 48 65
# 10 63 80
# 11 83 100
# 12 103 120
# 13 30 35
# 14 20 55
# 15 45 50
# 16 35 30
# 17 25 50
# 18 90 40
# 19 150 40
# 20 45 40
# 21 60 55
# 22 80 75
# 23 80 80
# 24 56 35
# 25 81 60
# 26 60 30
# 27 90 65
# 28 60 44
# 29 85 69
# 30 55 40
# 31 90 55
# 32 75 85
# 33 100 110
# 34 47 52
# 35 62 67
# 36 92 87
# 37 57 40
# 38 72 57
# 39 102 77
# 40 45 48
# 41 70 73
# 42 41 40
# 43 76 75
# 44 45 20
# 45 70 45
# 46 45 35
# 47 80 70
# 48 50 55
# 49 65 70
# 50 80 85
# 51 70 55
# 52 95 80
# 53 55 50
# 54 65 60
# 55 55 25
# 56 80 50
# 57 45 35
# 58 70 60
# 59 52 48
# 60 82 78
# 61 80 35
# 62 105 60
# 63 70 45
# 64 110 80
# 65 50 40
# 66 65 65
# 67 95 95
# 68 20 15
# 69 35 30
# 70 50 45
# 71 50 65
# 72 80 50
# 73 100 70
# 74 130 80
# 75 75 35
# 76 90 50
# 77 105 65
# 78 40 35
# 79 70 65
# 80 80 100
# 81 95 115
# 82 120 130
# 83 85 55
# 84 100 70
# 85 65 65
# 86 75 110
# 87 75 180
# 88 35 70
# ...

# %%
import numpy as np

# %%
df.select_dtypes(include=[np.number]).dtypes
# Out:
# Total         int64
# HP            int64
# Attack        int64
# Defense       int64
# Sp. Atk       int64
# Sp. Def       int64
# Speed         int64
# Generation    int64
# dtype: object

# %%
df.describe(include='all')
# Out:
#             Name Type 1  Type 2      Total          HP      Attack  \
# count        800    800     414  800.00000  800.000000  800.000000
# unique       800     18      18        NaN         NaN         NaN
# top     Lillipup  Water  Flying        NaN         NaN         NaN
# freq           1    112      97        NaN         NaN         NaN
# mean         NaN    NaN     NaN  435.10250   69.258750   79.001250
# std          NaN    NaN     NaN  119.96304   25.534669   32.457366
# min          NaN    NaN     NaN  180.00000    1.000000    5.000000
# 25%          NaN    NaN     NaN  330.00000   50.000000   55.000000
# 50%          NaN    NaN     NaN  450.00000   65.000000   75.000000
# 75%          NaN    NaN     NaN  515.00000   80.000000  100.000000
# max          NaN    NaN     NaN  780.00000  255.000000  190.000000
#
#            Defense     Sp. Atk     Sp. Def       Speed  Generation Legendary
# count   800.000000  800.000000  800.000000  800.000000   800.00000       800
# ...

# %%
df.drop('Type 1', axis = 1)
# Out:
#                       Name  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur  Poison    318  45      49       49       65
# 1                  Ivysaur  Poison    405  60      62       63       80
# 2                 Venusaur  Poison    525  80      82       83      100
# 3    VenusaurMega Venusaur  Poison    625  80     100      123      122
# 4               Charmander     NaN    309  39      52       43       60
# ..                     ...     ...    ...  ..     ...      ...      ...
# 795                Diancie   Fairy    600  50     100      150      100
# 796    DiancieMega Diancie   Fairy    700  50     160      110      160
# 797    HoopaHoopa Confined   Ghost    600  80     110       60      150
# 798     HoopaHoopa Unbound    Dark    680  80     160       60      170
# 799              Volcanion   Water    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df.mean(axis = 1)
# Out:
# 0       70.777778
# 1       90.111111
# 2      116.777778
# 3      139.000000
# 4       68.777778
#           ...
# 795    134.111111
# 796    156.333333
# 797    134.111111
# 798    151.888889
# 799    134.111111
# Length: 800, dtype: float64

# %%
df.Name.str.upper()
# Out:
# 0                  BULBASAUR
# 1                    IVYSAUR
# 2                   VENUSAUR
# 3      VENUSAURMEGA VENUSAUR
# 4                 CHARMANDER
#                ...
# 795                  DIANCIE
# 796      DIANCIEMEGA DIANCIE
# 797      HOOPAHOOPA CONFINED
# 798       HOOPAHOOPA UNBOUND
# 799                VOLCANION
# Name: Name, Length: 800, dtype: object

# %%
df.Name.str.contains("Fire").sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df.Attack.astype(object)
# Out:
# 0       49
# 1       62
# 2       82
# 3      100
# 4       52
#       ...
# 795    100
# 796    160
# 797    110
# 798    160
# 799    110
# Name: Attack, Length: 800, dtype: object

# %%
df.Attack.mean()
# Out:
# 79.00125

# %%
df.groupby('Type 1').Attack.max()
# Out:
# Type 1
# Bug         185
# Dark        150
# Dragon      180
# Electric    123
# Fairy       131
# Fighting    145
# Fire        160
# Flying      115
# Ghost       165
# Grass       132
# Ground      180
# Ice         130
# Normal      160
# Poison      106
# Psychic     190
# Rock        165
# Steel       150
# Water       155
# Name: Attack, dtype: int64

# %%
df.groupby('Type 2').Attack.agg(['count', 'min', 'mean', 'max'])
# Out:
#           count  min        mean  max
# Type 2
# Bug           3   50   90.000000  125
# Dark         20   63  109.800000  164
# Dragon       18   30   94.444444  130
# Electric      6   38   72.666667  150
# Fairy        23   20   61.608696  160
# Fighting     26   61  112.846154  190
# Fire         12   30   81.250000  180
# Flying       97   20   80.288660  180
# Ghost        14   40   84.142857  150
# Grass        25   30   74.160000  110
# Ground       35   45   89.857143  170
# Ice          14   59   98.000000  170
# Normal        4   38   52.750000   68
# Poison       34   25   67.588235  150
# Psychic      33   24   74.696970  145
# Rock         14   10   84.000000  140
# Steel        22   35   92.590909  150
# Water        14   30   70.142857  115

# %%
# %matplotlib inline

# %%
df.groupby('Type 2').Attack.mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Type 2'>

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
# %matplotlib inline

# %%
df['Type 1'].count().plot(kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-7bb3de2ccf4f> in <module>
# ----> 1 df['Type 1'].count().plot(kind = 'bar')
#
# AttributeError: 'numpy.int32' object has no attribute 'plot'

# %%
df.isnull().count()
# Out:
# Name          800
# Type 1        800
# Type 2        800
# Total         800
# HP            800
# Attack        800
# Defense       800
# Sp. Atk       800
# Sp. Def       800
# Speed         800
# Generation    800
# Legendary     800
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df[df['Type 2'].isnull()]
# Out:
#            Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4    Charmander    Fire    NaN    309   39      52       43       60       50
# 5    Charmeleon    Fire    NaN    405   58      64       58       80       65
# 9      Squirtle   Water    NaN    314   44      48       65       50       64
# 10    Wartortle   Water    NaN    405   59      63       80       65       80
# 11    Blastoise   Water    NaN    530   79      83      100       85      105
# ..          ...     ...    ...    ...  ...     ...      ...      ...      ...
# 775     Sliggoo  Dragon    NaN    452   68      75       53       83      113
# 776      Goodra  Dragon    NaN    600   90     100       70      110      150
# 788    Bergmite     Ice    NaN    304   55      69       85       32       35
# 789     Avalugg     Ice    NaN    514   95     117      184       44       46
# 792     Xerneas   Fairy    NaN    680  126     131       95      131       98
#
# ...

# %%
df.shape
# Out:
# (800, 12)

# %%
df.dropna(how='any').shape
# Out:
# (414, 12)

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.loc[23, 'Type 1']
# Out:
# 'Normal'

# %%
df.set_index("HP")
# Out:
#                      Name   Type 1  Type 2  Total  Attack  Defense  Sp. Atk  \
# HP
# 45              Bulbasaur    Grass  Poison    318      49       49       65
# 60                Ivysaur    Grass  Poison    405      62       63       80
# 80               Venusaur    Grass  Poison    525      82       83      100
# 80  VenusaurMega Venusaur    Grass  Poison    625     100      123      122
# 39             Charmander     Fire     NaN    309      52       43       60
# ..                    ...      ...     ...    ...     ...      ...      ...
# 50                Diancie     Rock   Fairy    600     100      150      100
# 50    DiancieMega Diancie     Rock   Fairy    700     160      110      160
# 80    HoopaHoopa Confined  Psychic   Ghost    600     110       60      150
# 80     HoopaHoopa Unbound  Psychic    Dark    680     160       60      170
# 80              Volcanion     Fire   Water    600     110      120      130
#
#     Sp. Def  Speed  Generation  Legendary
# HP
# ...

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.shape
# Out:
# (800, 12)

# %%
df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.Name.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df.loc[[0, 1, 4], :]
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 4     65           1      False

# %%
df.loc[:, "HP" : "Speed"]
# Out:
#      HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0    45      49       49       65       65     45
# 1    60      62       63       80       80     60
# 2    80      82       83      100      100     80
# 3    80     100      123      122      120     80
# 4    39      52       43       60       50     65
# ..   ..     ...      ...      ...      ...    ...
# 795  50     100      150      100      150     50
# 796  50     160      110      160      110    110
# 797  80     110       60      150      130     70
# 798  80     160       60      170      130     80
# 799  80     110      120      130       90     70
#
# [800 rows x 6 columns]

# %%
df.loc[df.Attack == 69, :]
# Out:
#                     Name Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 460  WormadamTrash Cloak    Bug    Steel    424  60      69       95       69
# 507             Lumineon  Water      NaN    460  69      69       76       69
# 723              Delphox   Fire  Psychic    534  75      69       72      114
# 788             Bergmite    Ice      NaN    304  55      69       85       32
#
#      Sp. Def  Speed  Generation  Legendary
# 460       95     36           4      False
# 507       86     91           4      False
# 723      100    104           6      False
# 788       35     28           6      False

# %%
df.iloc[:, 0:4]
# Out:
#                       Name   Type 1  Type 2  Total
# 0                Bulbasaur    Grass  Poison    318
# 1                  Ivysaur    Grass  Poison    405
# 2                 Venusaur    Grass  Poison    525
# 3    VenusaurMega Venusaur    Grass  Poison    625
# 4               Charmander     Fire     NaN    309
# ..                     ...      ...     ...    ...
# 795                Diancie     Rock   Fairy    600
# 796    DiancieMega Diancie     Rock   Fairy    700
# 797    HoopaHoopa Confined  Psychic   Ghost    600
# 798     HoopaHoopa Unbound  Psychic    Dark    680
# 799              Volcanion     Fire   Water    600
#
# [800 rows x 4 columns]

# %%
df.iloc[0:40, :]
# Out:
#      #                       Name    Type 1  Type 2  Total  HP  Attack  \
# 0    1                  Bulbasaur     Grass  Poison    318  45      49
# 1    2                    Ivysaur     Grass  Poison    405  60      62
# 2    3                   Venusaur     Grass  Poison    525  80      82
# 3    3      VenusaurMega Venusaur     Grass  Poison    625  80     100
# 4    4                 Charmander      Fire     NaN    309  39      52
# 5    5                 Charmeleon      Fire     NaN    405  58      64
# 6    6                  Charizard      Fire  Flying    534  78      84
# 7    6  CharizardMega Charizard X      Fire  Dragon    634  78     130
# 8    6  CharizardMega Charizard Y      Fire  Flying    634  78     104
# 9    7                   Squirtle     Water     NaN    314  44      48
# 10   8                  Wartortle     Water     NaN    405  59      63
# 11   9                  Blastoise     Water     NaN    530  79      83
# ...

# %%
df.HP.duplicated().sum()
# Out:
# 706

# %%
df.duplicated().sum()
# Out:
# 0

# %%
 df['Sp. Atk'].duplicated().sum()
# Out:
# 695

# %%
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Length: 800, dtype: bool

# %%
df.loc[df.Attack.duplicated(), :]
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 20    16               Pidgey   Normal  Flying    251  40      45       40
# 23    18  PidgeotMega Pidgeot   Normal  Flying    579  83      80       80
# 26    21              Spearow   Normal  Flying    262  40      60       30
# 27    22               Fearow   Normal  Flying    442  65      90       65
# 28    23                Ekans   Poison     NaN    288  35      60       44
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df.Total.duplicated(keep = 'first'), :]
# Out:
#        #                       Name   Type 1  Type 2  Total  HP  Attack  \
# 5      5                 Charmeleon     Fire     NaN    405  58      64
# 8      6  CharizardMega Charizard Y     Fire  Flying    634  78     104
# 10     8                  Wartortle    Water     NaN    405  59      63
# 16    13                     Weedle      Bug  Poison    195  40      35
# 17    14                     Kakuna      Bug  Poison    205  45      25
# ..   ...                        ...      ...     ...    ...  ..     ...
# 795  719                    Diancie     Rock   Fairy    600  50     100
# 796  719        DiancieMega Diancie     Rock   Fairy    700  50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799  721                  Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.Attack.drop_duplicates(keep='last')
# Out:
# 39     102
# 141    155
# 163    190
# 175     46
# 217     33
#       ...
# 791     70
# 793    131
# 795    100
# 798    160
# 799    110
# Name: Attack, Length: 111, dtype: int64

# %%
df.drop_duplicates(subset=['Attack', 'HP']).sum()
# Out:
# #                                                        176656
# Name          BulbasaurIvysaurVenusaurVenusaurMega VenusaurC...
# Type 1        GrassGrassGrassGrassFireFireFireFireFireWaterW...
# Total                                                    225966
# HP                                                        37340
# Attack                                                    42043
# Defense                                                   37644
# Sp. Atk                                                   37192
# Sp. Def                                                   36807
# Speed                                                     34940
# Generation                                                 1630
# Legendary                                                    40
# dtype: object

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass    Poison    318   45      49
# 1      2                    Ivysaur     Grass    Poison    405   60      62
# 2      3                   Venusaur     Grass    Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 4      4                 Charmander      Fire       NaN    309   39      52
# 5      5                 Charmeleon      Fire       NaN    405   58      64
# 6      6                  Charizard      Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 9      7                   Squirtle     Water       NaN    314   44      48
# 10     8                  Wartortle     Water       NaN    405   59      63
# ...

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
df['x'] = df.HP * df.Attack * 1000

# %%
df
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass    Poison    318   45      49
# 1      2                    Ivysaur     Grass    Poison    405   60      62
# 2      3                   Venusaur     Grass    Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 4      4                 Charmander      Fire       NaN    309   39      52
# 5      5                 Charmeleon      Fire       NaN    405   58      64
# 6      6                  Charizard      Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 9      7                   Squirtle     Water       NaN    314   44      48
# 10     8                  Wartortle     Water       NaN    405   59      63
# ...

# %%
pd.set_option('display.float_format', '{:,}'.format)

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# x              int64
# dtype: object

# %%
df.x = df.x.astype('float64')

# %%
df
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass    Poison    318   45      49
# 1      2                    Ivysaur     Grass    Poison    405   60      62
# 2      3                   Venusaur     Grass    Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 4      4                 Charmander      Fire       NaN    309   39      52
# 5      5                 Charmeleon      Fire       NaN    405   58      64
# 6      6                  Charizard      Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 9      7                   Squirtle     Water       NaN    314   44      48
# 10     8                  Wartortle     Water       NaN    405   59      63
# ...

# %%
pd.DataFrame({'id':[100, 101, 102, 103, 104, 105], 'color':['red', 'blue', 'green', 'black', 'white', 'poop']}, columns=['color', 'id'])
# Out:
#    color   id
# 0    red  100
# 1   blue  101
# 2  green  102
# 3  black  103
# 4  white  104
# 5   poop  105

# %%
pd.DataFrame([[100, 'red'],[101, 'blue'],[102, 'green']], columns=['id', 'color'])
# Out:
#     id  color
# 0  100    red
# 1  101   blue
# 2  102  green

# %%
pd.DataFrame({'student id':np.arange(100000, 100100, 1), 'test':np.random.randint(60, 101, 100)}).set_index('student id')
# Out:
#             test
# student id
# 100000        84
# 100001        92
# 100002        91
# 100003        62
# 100004        99
# 100005        89
# 100006        67
# 100007        81
# 100008        70
# 100009        79
# 100010        82
# 100011        72
# 100012        89
# 100013        64
# 100014        90
# 100015        98
# 100016        68
# 100017        66
# 100018        65
# 100019        92
# 100020        92
# 100021        80
# 100022        92
# 100023        88
# 100024        69
# 100025        89
# 100026        88
# 100027        93
# 100028        70
# 100029        63
# 100030        81
# 100031        80
# 100032        71
# 100033        84
# 100034        83
# 100035        91
# 100036        70
# 100037        80
# 100038        73
# 100039        90
# 100040        90
# 100041        60
# 100042        84
# 100043        85
# 100044        79
# 100045        91
# 100046        95
# 100047        83
# 100048        70
# 100049       100
# ...

# %%
S = pd.Series(np.random.randint(69, 420, 100), name = 'dank')
S
# Out:
# 0      70
# 1     108
# 2     292
# 3     293
# 4     284
# 5     244
# 6     397
# 7     252
# 8     371
# 9     372
# 10     69
# 11    307
# 12    184
# 13    189
# 14    389
# 15    398
# 16    406
# 17    175
# 18    263
# 19    295
# 20    146
# 21     69
# 22    128
# 23    231
# 24    298
# 25    369
# 26    186
# 27    309
# 28    329
# 29    345
# 30    134
# 31    390
# 32    204
# 33    268
# 34    328
# 35    222
# 36     94
# 37    406
# 38    346
# 39    367
# 40    292
# 41    368
# 42    200
# 43    399
# 44    166
# 45    349
# 46    327
# 47     90
# 48    193
# 49    126
# 50    397
# 51    312
# 52    333
# 53    236
# 54    148
# 55    176
# 56    393
# 57    341
# 58    406
# 59    132
# 60    187
# 61    377
# 62    187
# 63    130
# 64    410
# 65    163
# 66     95
# 67     93
# 68    246
# 69    189
# 70    404
# 71    222
# 72    283
# 73    138
# 74    371
# 75    133
# 76    375
# 77    146
# 78    302
# 79     99
# 80    150
# 81     83
# 82    300
# ...

# %%
pd.concat([df, S], axis = 1)
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass    Poison    318   45      49
# 1      2                    Ivysaur     Grass    Poison    405   60      62
# 2      3                   Venusaur     Grass    Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 4      4                 Charmander      Fire       NaN    309   39      52
# 5      5                 Charmeleon      Fire       NaN    405   58      64
# 6      6                  Charizard      Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 9      7                   Squirtle     Water       NaN    314   44      48
# 10     8                  Wartortle     Water       NaN    405   59      63
# ...

# %%
df['LegenNum'] = df.Legendary.map({True:1, False:0})

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.loc[:, ['Legendary','LegenNum']]
# Out:
#      Legendary  LegenNum
# 0        False         0
# 1        False         0
# 2        False         0
# 3        False         0
# 4        False         0
# ..         ...       ...
# 795       True         1
# 796       True         1
# 797       True         1
# 798       True         1
# 799       True         1
#
# [800 rows x 2 columns]

# %%
df['NameLen'] = df.Name.apply(len)
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df['Total_ceil'] = df.Total.apply(np.ceil)
df.loc[:, ['Total', 'Total_ceil']]
# Out:
#      Total  Total_ceil
# 0      318       318.0
# 1      405       405.0
# 2      525       525.0
# 3      625       625.0
# 4      309       309.0
# ..     ...         ...
# 795    600       600.0
# 796    700       700.0
# 797    600       600.0
# 798    680       680.0
# 799    600       600.0
#
# [800 rows x 2 columns]

# %%
df.loc[:, 'Total':'Speed'].applymap(float)
# Out:
#      Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0    318.0  45.0    49.0     49.0     65.0     65.0   45.0
# 1    405.0  60.0    62.0     63.0     80.0     80.0   60.0
# 2    525.0  80.0    82.0     83.0    100.0    100.0   80.0
# 3    625.0  80.0   100.0    123.0    122.0    120.0   80.0
# 4    309.0  39.0    52.0     43.0     60.0     50.0   65.0
# ..     ...   ...     ...      ...      ...      ...    ...
# 795  600.0  50.0   100.0    150.0    100.0    150.0   50.0
# 796  700.0  50.0   160.0    110.0    160.0    110.0  110.0
# 797  600.0  80.0   110.0     60.0    150.0    130.0   70.0
# 798  680.0  80.0   160.0     60.0    170.0    130.0   80.0
# 799  600.0  80.0   110.0    120.0    130.0     90.0   70.0
#
# [800 rows x 7 columns]

# %%
stocks = pd.read_csv('http://bit.ly/smallstocks')

# %%
stocks
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT
# 5  2016-10-04   31.35  18460400   CSCO
# 6  2016-10-05   57.64  16726400   MSFT
# 7  2016-10-05   31.59  11808600   CSCO
# 8  2016-10-05  113.05  21453100   AAPL

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
stocks.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
stocks.groupby('Symbol').Close.mean()
# Out:
# Symbol
# AAPL    112.856667
# CSCO     31.480000
# MSFT     57.433333
# Name: Close, dtype: float64
