# %%
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
x = [10, 20, 30, 40]
y = [0, 15, 10, 25]

# %%
plt.plot(x, y)

# %%
sns.set()

# %%
plt.plot(x, y)

# %%
sns.set_style('dark')

# %%
plt.plot(x, y)

# %%
cars = sns.load_dataset('mpg')

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.dropna(inplace=True)
cars.shape
# Out:
# (392, 9)

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
plt.figure(figsize=(10,10))
sns.relplot(x = 'model_year', y='mpg', col='origin', hue='cylinders', data=cars)

# %%
cars.shape
# Out:
# (392, 9)

# %%
sns.kdeplot(cars.horsepower)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, shade=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, bw_adjust = 0.1)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, cumulative=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg)

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg, n_levels=20)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg, shade=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.set_style('whitegrid')
sns.kdeplot(x=cars.horsepower, y=cars.mpg, shade=True, thresh=0.1)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.set_style('whitegrid')
sns.kdeplot(x=cars.horsepower, y=cars.mpg, shade=True, thresh=0.1, cbar=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
cars.shape
# Out:
# (392, 9)

# %%
sns.displot(cars.weight)

# %%
sns.displot(cars.weight, kde=True)

# %%
sns.histplot(cars.weight)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
sns.histplot(cars.weight, kde=True)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
sns.displot(cars.weight, rug=True, kde=True)

# %%
sns.displot(cars.weight, bins=20)

# %%
sns.displot(cars.weight, bins=[1500, 2000, 2500, 3500, 5200])

# %%
sns.histplot(cars.weight, alpha=1, color='c')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
sns.histplot(cars.weight, kde=True ,lw=10)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
sns.displot(cars.weight, kde=True, color='c', rug=True, rug_kws={'height': 0.15, 'color': 'xkcd:navy'})

# %%
 cars.shape
# Out:
# (392, 9)

# %%
cars.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
cars2 = cars[cars.cylinders.isin([4,6,8])]

# %%
sns.boxplot(cars2.mpg)
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
cars.mpg.describe()
# Out:
# count    392.000000
# mean      23.445918
# std        7.805007
# min        9.000000
# 25%       17.000000
# 50%       22.750000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
cars.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
sns.boxplot(x=cars.origin, y=cars.mpg)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin', y='mpg', data=cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin', y='mpg', hue='cylinders', data=cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
cars.model_year.describe()
# Out:
# count    392.000000
# mean      75.979592
# std        3.683737
# min       70.000000
# 25%       73.000000
# 50%       76.000000
# 75%       79.000000
# max       82.000000
# Name: model_year, dtype: float64

# %%
cars['newer_model'] = cars.model_year > 79

# %%
cars['newer_model'].value_counts()
# Out:
# False    307
# True      85
# Name: newer_model, dtype: int64

# %%
sns.boxplot(x='origin', y='mpg', hue='newer_model', data=cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars,
            order=['japan', 'europe', 'usa'])#
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', hue='newer_model',data=cars, 
            order=['japan', 'europe', 'usa'], hue_order=[True, False])#hue added
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', 
            data=cars, order=['japan', 'europe', 'usa'], color='c')#one color
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', hue='newer_model',data=cars, 
            order=['japan', 'europe', 'usa'], hue_order=[True, False],
            color='c')#huewise with color
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars, order=['japan', 'europe', 'usa'],
            color='c', width=0.5)#changing width
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars,
            order=['japan', 'europe', 'usa'], color='c',
           whis=1)#changes whiskers
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg',
            data=cars, order=['japan', 'europe', 'usa'], color='c',
           fliersize=2)#size of diamonds
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>
